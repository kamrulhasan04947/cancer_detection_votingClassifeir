# %% [markdown]
# <a href="https://colab.research.google.com/github/kamrulhasan04947/cancer_detection_votingClassifeir/blob/main/practice_data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.randn(1000), index=pd.date_range('2000-01-01', periods=1000), columns=['Values'])

# %%
df.head()
# Out:
#               Values
# 2000-01-01  0.956268
# 2000-01-02 -1.471993
# 2000-01-03 -1.455453
# 2000-01-04  1.083054
# 2000-01-05 -0.825466

# %%
df.head(200).plot()

# %%
df.head(200).plot(kind='bar')

# %%
ndf = sns.load_dataset('iris')

# %%
ndf.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ndf.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
ndf['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
ndf.duplicated().sum()
# Out:
# 1

# %%
ndf.drop_duplicates(inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
laben = LabelEncoder()

# %%
ndf['species'] = laben.fit_transform(ndf['species'])

# %%
ndf['species'].unique()
# Out:
# array([0, 1, 2])

# %%
ndf.head().dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species           int64
# dtype: object

# %%
ndf.shape
# Out:
# (149, 5)

# %%
ndf.head(50).plot(kind='bar')

# %%
ndf.plot(kind='bar', figsize=(20, 20))

# %%
ndf.plot(figsize=(15, 15))

# %%
ndf.iloc[0].plot.bar()

# %%
ndf['sepal_length'].head(20).plot.bar(figsize=(15, 10))

# %%
ndf['sepal_length'].plot.hist()

# %%
ndf.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
ndf.plot.hist()

# %%
ndf.plot(kind='hist', bins=50)

# %%
ndf.plot(kind='hist', bins=50, orientation='horizontal')

# %%
ndf.hist(color='green', alpha=0.5, figsize=(8, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc8c433fad0>,
# ...
#       dtype=object)

# %%
ndf.plot(kind='scatter', x='sepal_length', y='sepal_width')

# %%
pd.plotting.scatter_matrix(ndf, figsize=(15, 8), color='green')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc8c3a277d0>,
# ...
#       dtype=object)

# %%
ndf.plot.scatter(x='sepal_length', y='sepal_width', c='petal_width')

# %%
ndf.iloc[50].plot(kind='pie', figsize=(5, 5), autopct="%.2f")

# %%
ndf[ndf['species'] == 1]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  species
# 50           7.0          3.2           4.7          1.4        1
# 51           6.4          3.2           4.5          1.5        1
# 52           6.9          3.1           4.9          1.5        1
# 53           5.5          2.3           4.0          1.3        1
# 54           6.5          2.8           4.6          1.5        1
# 55           5.7          2.8           4.5          1.3        1
# 56           6.3          3.3           4.7          1.6        1
# 57           4.9          2.4           3.3          1.0        1
# 58           6.6          2.9           4.6          1.3        1
# 59           5.2          2.7           3.9          1.4        1
# 60           5.0          2.0           3.5          1.0        1
# 61           5.9          3.0           4.2          1.5        1
# 62           6.0          2.2           4.0          1.0        1
# ...

# %%
ndf.head(5).T.plot(kind='pie', subplots=True, figsize=(30, 30), autopct='%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fc8bfaa4190>,
# ...
#       dtype=object)

# %% [markdown]
# # **Seaborn**
#
# ---

# %%
import seaborn as sns

# %%
n1 = sns.load_dataset('tips')

# %%
n1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
n1.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
#relational ploting/scatter ploting
sns.relplot(x='total_bill', y='tip', data=n1)

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', data=n1)

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', style='sex', size='size', data=n1)

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', style='sex', size='size', col='day', data=n1)

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', style='sex', size='size', col='time', data=n1)

# %%
sns.scatterplot(x='day', y='tip', data=n1)

# %%
sns.scatterplot(x='total_bill', y='tip', data=n1)

# %%
sns.catplot(x='day', y='tip', data=n1)

# %%
sns.catplot(x='day', y='tip', data=n1, kind='swarm')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x='day', y='tip', data=n1, kind='swarm', hue='size')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x='day', y='tip', data=n1, kind='box', hue='size')

# %%
sns.catplot(x='day', y='tip', data=n1, kind='box')

# %%
sns.pairplot(data=n1, hue='size')

# %%
sns.pairplot(data=n1)

# %%
list_1 =["A", "B", "C"]

# %%
list_2 = list_1

# %%
print(list_2)
# Out:
# ['A', 'B', 'C']

# %%
list_3 = list_2
print(list_3)
# Out:
# ['A', 'B', 'C']

# %%
del list_1[0]

# %%
print(list_2)
# Out:
# ['B', 'C']

# %%
del list_2[0]
print(list_3)
# Out:
# ['C']

# %%
l_1 = ["A", "B", "C"]
l_2 = l_1

# %%
l_3 = l_2

# %%
del l_1[0]

# %%
print(l_2)
# Out:
# ['B', 'C']

# %%
del l_2

# %%
print(l_3)
# Out:
# ['B', 'C']

# %%
ml_1 = ["A", "B", "C"]
ml_2 = ml_1[:]
del ml_1[0]

# %%
print(ml_2)
# Out:
# ['A', 'B', 'C']

# %%
ml_3 = ml_2[:]
del ml_2[0]

# %%
print(ml_3)
# Out:
# ['A', 'B', 'C']

# %%
i = 2
while i >= 0:
      print('*')
      i -=2
# Out:
# *
# *

# %%
for i in range(-1, 1):
  print('#')
# Out:
# #
# #

# %%
nums = []
vls = nums[:]
vls.append(1)

# %%
print(len(vls), len(nums))
print(nums)
# Out:
# 1 0
# []

# %%
def lst(n):
  lsts = []
  for i in range(0 , n):
    lsts.insert(0, i)
  return lsts

# %%
print(lst(5))
# Out:
# [4, 3, 2, 1, 0]
